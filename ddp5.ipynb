# %%
my_list= ['motor', 1, 'mobil', 'toyota']
my_list.append ('suzuki')
my_list.remove (1)
my_list.insert (2, 'honda')
print (my_list)

my_list=[1,2,3,4]
my_poplist=my_list
print(my_list)
print(my_poplist)

#tuple
my_tuple=(1,2,3,4)
print(my_tuple[1])

#dictionary
my_dict={
'nama':'angelsjhsj',
'nim':'17384939',
'rombel':'ti12',
}
print(my_dict)

kontak={'budi':'037474784',
'ibu budi' : '028283883',
'budi' : '20202020'}
print(kontak)
# Out:
# ['motor', 'mobil', 'honda', 'toyota', 'suzuki']
# [1, 2, 3, 4]
# [1, 2, 3, 4]
# 2
# {'nama': 'angelsjhsj', 'nim': '17384939', 'rombel': 'ti12'}
# {'budi': '20202020', 'ibu budi': '028283883'}

# %%
warna_lampu = input("masukkan warna lampu")

match warna_lampu:
 case "merah" :
  print ("berhenti")
 case "kuning" :
  print ("hati hati")
 case _:
  print ("error")

# %%
kendaraan =['beat karbu', 'motor',200, 'pink', 2]
print(kendaraan)
kendaraan.append('13jt')
kendaraan.append('matic')
print(kendaraan)

kendaraan.insert(2, 'honda')
print(kendaraan)

print(type(kendaraan[1]))
print(type(kendaraan[2]))
print(type(kendaraan[3]))
print(type(kendaraan[4]))
# Out:
# ['beat karbu', 'motor', 200, 'pink', 2]
# ['beat karbu', 'motor', 200, 'pink', 2, '13jt', 'matic']
# ['beat karbu', 'motor', 'honda', 200, 'pink', 2, '13jt', 'matic']
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %%
hitung_luas = input("pilih salah satu
 1. hitung luas persegi
 2. hitung luas lingkaran
 3. hitung luas segitiga
")

match hitung_luas:
 case 1:
 print('menghitung luas persegi')
 sisi = int(input('masukkan nilai sisi: '))
 hitung_luas_persegi = sisi**2
 print(f'jadi luas persegi dengan sisi (sisi) cm adalah (hitung_luas_persegi) cm^2')
 case _:
 print('pilihan tidak valid')
